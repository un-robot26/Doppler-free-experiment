# %%
'''
Python code for calculations of relavant physical quantities.
Goal:
Calculate the values of coupling constants A and B and their uncertainties
'''
### physical constants, SI units ###

# %%
### pull data from csv file and plot ###
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load the data
# Replace 'your_data.csv' with your actual filename
try:
    df = pd.read_csv('your_data.csv')

    # 2. Basic Data Inspection (Optional but helpful)
    # print(df.head()) 

    # 3. Create the plot
    plt.figure(figsize=(10, 6))
    
    # Replace 'Column_X' and 'Column_Y' with your actual header names
    plt.plot(df['Column_X'], df['Column_Y'], marker='o', linestyle='-', color='b', label='Data Trend')

    # 4. Add "The Nice Stuff" (Formatting)
    plt.title('Data Visualization from CSV', fontsize=14)
    plt.xlabel('X-Axis Label', fontsize=12)
    plt.ylabel('Y-Axis Label', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()

    # 5. Show the result
    plt.tight_layout()
    plt.show()

except FileNotFoundError:
    print("Error: The CSV file was not found. Check the file path!")
# Out:
# Error: The CSV file was not found. Check the file path!
